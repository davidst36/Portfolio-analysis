# %%
import pandas as pd
import yfinance as yf

# Download data for VOO only
voo = yf.download("VOO", start="2012-01-01", end="2024-09-16")

# Save the VOO data to a CSV
voo.to_csv("voo.csv")

# Read the VOO data back from CSV
voo_data = pd.read_csv("voo.csv", index_col=[0], parse_dates=[0])

# Display VOO data
print(voo_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03  116.900002  117.459999  116.599998  116.599998   92.829948
# 2012-01-04  116.440002  116.919998  115.959999  116.800003   92.989182
# 2012-01-05  116.279999  117.300003  115.680000  117.180000   93.291710
# 2012-01-06  117.300003  117.300003  116.480003  116.940002   93.100639
# 2012-01-09  117.139999  117.239998  116.540001  117.120003   93.243935
# ...                ...         ...         ...         ...         ...
# 2024-09-09  500.600006  503.369995  498.750000  502.230011  502.230011
# 2024-09-10  503.950012  504.709991  499.500000  504.299988  504.299988
# 2024-09-11  504.309998  510.440002  496.250000  509.459991  509.459991
# 2024-09-12  510.089996  514.140015  508.059998  513.840027  513.840027
# 2024-09-13  514.429993  517.530029  514.229980  516.570007  516.570007
#
#              Volume
# Date
# ...

# %%
voo_data.loc["1-2024":"8-2024"].iplot(kind = "candle")

# %%
qf = cf.QuantFig(df = voo_data.loc["1-2024":"8-2024"])
qf.add_sma(periods = 20)
qf.iplot()
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# C:\Users\david\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
